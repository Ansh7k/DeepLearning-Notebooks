# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.shape
# Out:
# (100, 4)

# %%
df = pd.read_csv('placement.csv')

# %%
df.shape
# Out:
# (100, 4)

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
sns.scatterplot(x=df['cgpa'],y= df['iq'],hue =df['placement'])
# Out:
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[11., 47.]])

# %%
p.intercept_
# Out:
# array([-72.])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values,y.values,clf=p,legend=2)
# Out:
# C:\Users\kadia\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
